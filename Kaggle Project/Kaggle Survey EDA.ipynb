# %% [markdown]
# ### 필요한 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Kaggle Survey 데이터 불러오기

# %%
data = pd.read_csv("./data/kaggle_survey_2020_responses.csv", encoding = "utf-8")
data
# Out:
# C:\Users\chahn\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                    1838                        35-39
# 2                                  289287                        30-34
# 3                                     860                        35-39
# 4                                     507                        30-34
# ...                                   ...                          ...
# 20032                                 126                        18-21
# 20033                                 566                        55-59
# 20034                                 238                        30-34
# 20035                                 625                        22-24
# 20036                                1031                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# 4                                         Man
# ...                                       ...
# 20032                                     Man
# 20033                                   Woman
# 20034                                     Man
# 20035                                     Man
# 20036                                     Man
#
#                                                       Q3  \
# 0              In which country do you currently reside?
# 1                                               Colombia
# 2                               United States of America
# 3                                              Argentina
# 4                               United States of America
# ...                                                  ...
# 20032                                             Turkey
# 20033  United Kingdom of Great Britain and Northern I...
# 20034                                             Brazil
# 20035                                              India
# 20036                                           Pakistan
#
#                                                       Q4  \
# 0      What is the highest level of formal education ...
# 1                                        Doctoral degree
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# ...                                                  ...
# 20032  Some college/university study without earning ...
# 20033                                    Master’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                                                       Q5  \
# 0      Select the title most similar to your current ...
# 1                                                Student
# 2                                          Data Engineer
# 3                                      Software Engineer
# 4                                         Data Scientist
# ...                                                  ...
# 20032                                                NaN
# 20033                             Currently not employed
# 20034                                 Research Scientist
# 20035                                  Software Engineer
# 20036                          Machine Learning Engineer
#
#                                                       Q6  \
# 0      For how many years have you been writing code ...
# 1                                             5-10 years
# 2                                             5-10 years
# 3                                            10-20 years
# 4                                             5-10 years
# ...                                                  ...
# 20032                                                NaN
# 20033                                          20+ years
# 20034                                          < 1 years
# 20035                                          3-5 years
# 20036                                          < 1 years
#
#                                                Q7_Part_1  \
# 0      What programming languages do you use on a reg...
# 1                                                 Python
# 2                                                 Python
# 3                                                    NaN
# 4                                                 Python
# ...                                                  ...
# 20032                                                NaN
# 20033                                             Python
# 20034                                             Python
# 20035                                             Python
# 20036                                             Python
#
#                                                Q7_Part_2  \
# 0      What programming languages do you use on a reg...
# 1                                                      R
# 2                                                      R
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                                Q7_Part_3  ...  \
# 0      What programming languages do you use on a reg...  ...
# 1                                                    SQL  ...
# 2                                                    SQL  ...
# 3                                                    NaN  ...
# 4                                                    SQL  ...
# ...                                                  ...  ...
# 20032                                                NaN  ...
# 20033                                                NaN  ...
# 20034                                                NaN  ...
# 20035                                                SQL  ...
# 20036                                                NaN  ...
#
#                                             Q35_B_Part_2  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                  Weights & Biases
# 20036                                  Weights & Biases
#
#                                             Q35_B_Part_3  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_4  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_5  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                           TensorBoard
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                       TensorBoard
# 20036                                                NaN
#
#                                             Q35_B_Part_6  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_7  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_8  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                            Trains
# 20036                                            Trains
#
#                                             Q35_B_Part_9  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                            Q35_B_Part_10  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                   None
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                               None
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                              Q35_B_OTHER
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
# [20037 rows x 355 columns]

# %% [markdown]
# ### 데이터 전처리
#
# - 교육상태와 관련이 있는 column들을 고릅니다.
#
# - Data Science 실무 경력과 관련된 column들을 고릅니다.

# %%
# edu_column
# ds_column
edu_column = ["Q4", "Q6", "Q15"]
ds_column = ["Q5", "Q20", "Q22"]

edit_data = data[edu_column + ds_column]
edit_data
# Out:
#                                                       Q4  \
# 0      What is the highest level of formal education ...
# 1                                        Doctoral degree
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# ...                                                  ...
# 20032  Some college/university study without earning ...
# 20033                                    Master’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                                                       Q6  \
# 0      For how many years have you been writing code ...
# 1                                             5-10 years
# 2                                             5-10 years
# 3                                            10-20 years
# 4                                             5-10 years
# ...                                                  ...
# 20032                                                NaN
# 20033                                          20+ years
# 20034                                          < 1 years
# 20035                                          3-5 years
# 20036                                          < 1 years
#
#                                                      Q15  \
# 0      For how many years have you used machine learn...
# 1                                              1-2 years
# 2                                              1-2 years
# 3                  I do not use machine learning methods
# 4                                              3-4 years
# ...                                                  ...
# 20032                                                NaN
# 20033                                          1-2 years
# 20034              I do not use machine learning methods
# 20035                                          1-2 years
# 20036                                       Under 1 year
#
#                                                       Q5  \
# 0      Select the title most similar to your current ...
# 1                                                Student
# 2                                          Data Engineer
# 3                                      Software Engineer
# 4                                         Data Scientist
# ...                                                  ...
# 20032                                                NaN
# 20033                             Currently not employed
# 20034                                 Research Scientist
# 20035                                  Software Engineer
# 20036                          Machine Learning Engineer
#
#                                                      Q20  \
# 0      What is the size of the company where you are ...
# 1                                                    NaN
# 2                               10,000 or more employees
# 3                                   1000-9,999 employees
# 4                                      250-999 employees
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                     0-49 employees
# 20035                           10,000 or more employees
# 20036                                     0-49 employees
#
#                                                      Q22
# 0      Does your current employer incorporate machine...
# 1                                                    NaN
# 2      We have well established ML methods (i.e., mod...
# 3                          No (we do not use ML methods)
# 4      We have well established ML methods (i.e., mod...
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034  We are exploring ML methods (and may one day p...
# 20035  We recently started using ML methods (i.e., mo...
# 20036                                      I do not know
#
# [20037 rows x 6 columns]

# %%
# null이 아닌 row만
edit_data[edit_data.isnull().any(axis=1)]
# Out:
#                                                       Q4          Q6  \
# 1                                        Doctoral degree  5-10 years
# 5                                        Master’s degree   3-5 years
# 6                                      Bachelor’s degree   < 1 years
# 7                                      Bachelor’s degree   3-5 years
# 8                                        Master’s degree   < 1 years
# ...                                                  ...         ...
# 20028                                    Master’s degree   3-5 years
# 20029                                    Master’s degree   < 1 years
# 20031                                    Master’s degree         NaN
# 20032  Some college/university study without earning ...         NaN
# 20033                                    Master’s degree   20+ years
#
#                                          Q15                      Q5  \
# 1                                  1-2 years                 Student
# 5                                        NaN       Software Engineer
# 6                                        NaN            Data Analyst
# 7                               Under 1 year                 Student
# 8                                  1-2 years                 Student
# ...                                      ...                     ...
# 20028  I do not use machine learning methods                 Student
# 20029  I do not use machine learning methods            Data Analyst
# 20031                                    NaN                     NaN
# 20032                                    NaN                     NaN
# 20033                              1-2 years  Currently not employed
#
#                   Q20  Q22
# 1                 NaN  NaN
# 5                 NaN  NaN
# 6                 NaN  NaN
# 7                 NaN  NaN
# 8                 NaN  NaN
# ...               ...  ...
# 20028             NaN  NaN
# 20029  0-49 employees  NaN
# 20031             NaN  NaN
# 20032             NaN  NaN
# 20033             NaN  NaN
#
# [9502 rows x 6 columns]

# %%
# 결측치 제거
final_data = edit_data.dropna()
final_data
# Out:
#                                                       Q4  \
# 0      What is the highest level of formal education ...
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# 9                                        Doctoral degree
# ...                                                  ...
# 20025                             I prefer not to answer
# 20030                                  Bachelor’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                                                       Q6  \
# 0      For how many years have you been writing code ...
# 2                                             5-10 years
# 3                                            10-20 years
# 4                                             5-10 years
# 9                                             5-10 years
# ...                                                  ...
# 20025                                          1-2 years
# 20030                                        10-20 years
# 20034                                          < 1 years
# 20035                                          3-5 years
# 20036                                          < 1 years
#
#                                                      Q15  \
# 0      For how many years have you used machine learn...
# 2                                              1-2 years
# 3                  I do not use machine learning methods
# 4                                              3-4 years
# 9                                              2-3 years
# ...                                                  ...
# 20025                                          1-2 years
# 20030              I do not use machine learning methods
# 20034              I do not use machine learning methods
# 20035                                          1-2 years
# 20036                                       Under 1 year
#
#                                                       Q5  \
# 0      Select the title most similar to your current ...
# 2                                          Data Engineer
# 3                                      Software Engineer
# 4                                         Data Scientist
# 9                                         Data Scientist
# ...                                                  ...
# 20025                          Machine Learning Engineer
# 20030                                              Other
# 20034                                 Research Scientist
# 20035                                  Software Engineer
# 20036                          Machine Learning Engineer
#
#                                                      Q20  \
# 0      What is the size of the company where you are ...
# 2                               10,000 or more employees
# 3                                   1000-9,999 employees
# 4                                      250-999 employees
# 9                                   1000-9,999 employees
# ...                                                  ...
# 20025                                     0-49 employees
# 20030                                  250-999 employees
# 20034                                     0-49 employees
# 20035                           10,000 or more employees
# 20036                                     0-49 employees
#
#                                                      Q22
# 0      Does your current employer incorporate machine...
# 2      We have well established ML methods (i.e., mod...
# 3                          No (we do not use ML methods)
# 4      We have well established ML methods (i.e., mod...
# 9      We have well established ML methods (i.e., mod...
# ...                                                  ...
# 20025                                      I do not know
# 20030                      No (we do not use ML methods)
# 20034  We are exploring ML methods (and may one day p...
# 20035  We recently started using ML methods (i.e., mo...
# 20036                                      I do not know
#
# [10535 rows x 6 columns]

# %% [markdown]
# ## 교육수준과 관련된 EDA
#
# - EDA에서는 다음과 같은 항목을 살펴봅니다.
#
# > 기본적인 빈도 분석
#
# > 히스토그램
#
# > Pie chart와 같은 plotting 기법들

# %% [markdown]
# ### Q4 column
#
# **"What is the highest level of formal education that you have attained or plan to attain with the next 2 years?"**
#
# - 기본적인 matplotlib(pyplot)을 이용하여 시각화를 해봅니다.

# %%
Q4 = final_data["Q4"]
Q4
# Out:
# 0        What is the highest level of formal education ...
# 2                                          Master’s degree
# 3                                        Bachelor’s degree
# 4                                          Master’s degree
# 9                                          Doctoral degree
#                                ...
# 20025                               I prefer not to answer
# 20030                                    Bachelor’s degree
# 20034                                      Master’s degree
# 20035                                    Bachelor’s degree
# 20036                                      Master’s degree
# Name: Q4, Length: 10535, dtype: object

# %%
# plt.hist
plt.figure(figsize=(12, 12))
plt.title("Histogram of Q4 column")
plt.xticks(rotation='vertical')
plt.hist(Q4)
plt.show()

# %%
plt.figure(figsize=(16, 12))
plt.pie(Q4.value_counts(),
       labels=Q4.value_counts().index,
       autopct='%d%%',
       startangle=90,
       textprops={'fontsize':12})
plt.axis('equal')
plt.title("Pie chart for Q4 column", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Pie chart for Q4 column')

# %% [markdown]
# ### Q6 column
# **For how many years have you been writing code and/or programming?**

# %%
Q6 = final_data["Q6"]
Q6
# Out:
# 0        For how many years have you been writing code ...
# 2                                               5-10 years
# 3                                              10-20 years
# 4                                               5-10 years
# 9                                               5-10 years
#                                ...
# 20025                                            1-2 years
# 20030                                          10-20 years
# 20034                                            < 1 years
# 20035                                            3-5 years
# 20036                                            < 1 years
# Name: Q6, Length: 10535, dtype: object

# %%
plt.figure(figsize=(12, 16))
# plt.hist
plt.hist(Q6)
plt.xticks(rotation='vertical')
plt.title("Histogram for Q6 column")
plt.show()

# %%
plt.figure(figsize=(24, 32))
plt.pie(Q6.value_counts(),
       labels=Q6.value_counts().index,
       autopct='%d%%',
       textprops={'fontsize':36})
plt.axis('equal')
plt.title("Pie chart for Q6 column", fontsize=48)
# Out:
# Text(0.5, 1.0, 'Pie chart for Q6 column')

# %% [markdown]
# ### Q15 column
#
# **For how many years have you used machine learning methods?**
#
# - seaborn을 이용해서 시각화를 해봅니다.

# %%
Q15 = final_data["Q15"]
Q15
# Out:
# 0        For how many years have you used machine learn...
# 2                                                1-2 years
# 3                    I do not use machine learning methods
# 4                                                3-4 years
# 9                                                2-3 years
#                                ...
# 20025                                            1-2 years
# 20030                I do not use machine learning methods
# 20034                I do not use machine learning methods
# 20035                                            1-2 years
# 20036                                         Under 1 year
# Name: Q15, Length: 10535, dtype: object

# %%
# countplot을 사용해봅니다
plt.figure(figsize=(16,8))
sns.countplot(y="Q15", data=final_data[1:])
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(Q15.value_counts(),
       labels=Q15.value_counts().index,
       autopct='%d%%',
        colors=sns.color_palette('hls',len(Q15.value_counts().index)),
       textprops={'fontsize':12})
plt.axis('equal')
plt.title("Pie chart for Q15 column", fontsize=16, pad=50)
plt.show()

# %% [markdown]
# ## 직업과 관련된 EDA
#
# - EDA에서는 다음과 같은 항목을 살펴봅니다.
#
# > 기본적인 빈도 분석
#
# > 히스토그램
#
# > Pie chart와 같은 plotting 기법들

# %% [markdown]
# ### Q5 column
#
# **Select the title most similar to your current role**
#
# - 기본적인 matplotlib(pyplot)을 이용하여 시각화를 해봅니다.

# %%
Q5 = final_data["Q5"][1:]
Q5
# Out:
# 2                    Data Engineer
# 3                Software Engineer
# 4                   Data Scientist
# 9                   Data Scientist
# 12              Research Scientist
#                    ...
# 20025    Machine Learning Engineer
# 20030                        Other
# 20034           Research Scientist
# 20035            Software Engineer
# 20036    Machine Learning Engineer
# Name: Q5, Length: 10534, dtype: object

# %%
Q5.value_counts()
# Out:
# Data Scientist               2429
# Software Engineer            1678
# Other                        1368
# Data Analyst                 1216
# Research Scientist           1024
# Machine Learning Engineer     946
# Business Analyst              605
# Product/Project Manager       545
# Data Engineer                 372
# Statistician                  241
# DBA/Database Engineer         110
# Name: Q5, dtype: int64

# %%
plt.figure(figsize=(12, 8))
# plt.hist(Q5) #범주형
plt.barh(Q5.value_counts().index, Q5.value_counts().values) #수치형
# plt.xticks(rotation='vertical')
plt.title("Histogram for Q5 column")
plt.show()

# %%
plt.figure(figsize=(16, 12))
#수치형
plt.pie(Q5.value_counts(),
       labels=Q5.value_counts().index,
       autopct='%d%%',
        colors=sns.color_palette('hls',len(Q5.value_counts().index)),
       textprops={'fontsize':24})
plt.axis('equal')
plt.title("Pie chart for Q5 column", fontsize=32, pad=50)
plt.show()

# %% [markdown]
# ### Q20 column
#
# **What is the size of the compnay where are employed?**
# - seaborn을 이용해서 시각화를 해봅니다.

# %%
Q20 = final_data["Q20"]
Q20
# Out:
# 0        What is the size of the company where you are ...
# 2                                 10,000 or more employees
# 3                                     1000-9,999 employees
# 4                                        250-999 employees
# 9                                     1000-9,999 employees
#                                ...
# 20025                                       0-49 employees
# 20030                                    250-999 employees
# 20034                                       0-49 employees
# 20035                             10,000 or more employees
# 20036                                       0-49 employees
# Name: Q20, Length: 10535, dtype: object

# %%
# sns.countplot을 사용해봅시다.
plt.figure(figsize=(8,6))
sns.countplot(y="Q20", data=final_data[1:])
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(Q20.value_counts(),
       labels=Q20.value_counts().index,
       autopct='%d%%',
        colors=sns.color_palette('hls',len(Q20.value_counts().index)),
       textprops={'fontsize':16})
plt.axis('equal')
plt.title("Pie chart for Q20 column", fontsize=24, pad=50)
plt.show()

# %% [markdown]
# ### Q22 column
#
# **Does your current employer incorporate machine learning methods into their business?**
# - seaborn을 이용해서 시각화를 해봅니다.

# %%
Q22 = final_data["Q22"][1:]
Q22
# Out:
# 2        We have well established ML methods (i.e., mod...
# 3                            No (we do not use ML methods)
# 4        We have well established ML methods (i.e., mod...
# 9        We have well established ML methods (i.e., mod...
# 12       We use ML methods for generating insights (but...
#                                ...
# 20025                                        I do not know
# 20030                        No (we do not use ML methods)
# 20034    We are exploring ML methods (and may one day p...
# 20035    We recently started using ML methods (i.e., mo...
# 20036                                        I do not know
# Name: Q22, Length: 10534, dtype: object

# %%
Q22.value_counts()
# Out:
# We are exploring ML methods (and may one day put a model into production)                    2253
# No (we do not use ML methods)                                                                2005
# We have well established ML methods (i.e., models in production for more than 2 years)       1881
# We recently started using ML methods (i.e., models in production for less than 2 years)      1765
# I do not know                                                                                1414
# We use ML methods for generating insights (but do not put working models into production)    1216
# Name: Q22, dtype: int64

# %%
plt.figure(figsize=(12, 16))
# To-Do
# plt.barh(Q22.value,_counts().index, Q22.value_counts().values)
sns.countplot(y="Q22", data=final_data[1:])
plt.show()

# %%
plt.figure(figsize=(32, 32))
plt.pie(Q22.value_counts(),
       labels=Q22.value_counts().index,
       autopct='%.2f%%',
        colors=sns.color_palette('hls',len(Q22.value_counts().index)),
       textprops={'fontsize':44})
plt.axis('equal')
plt.title("Pie chart for Q22 column", fontsize=48, pad=50)
plt.show()

# %%
set(data["Q3"]) # Republic of Korea, South Korea
korea = data[data["Q3"].isin(["Republic of Korea", "South Korea"])]
korea
# Out:
#       Time from Start to Finish (seconds)     Q1   Q2                 Q3  \
# 39                                    592  25-29  Man        South Korea
# 234                                  1439  35-39  Man  Republic of Korea
# 286                                   237  40-44  Man        South Korea
# 366                                 16200  25-29  Man  Republic of Korea
# 371                                   668  35-39  Man  Republic of Korea
# ...                                   ...    ...  ...                ...
# 19763                                 641  18-21  Man        South Korea
# 19845                                 201  25-29  Man        South Korea
# 19867                                 708  25-29  Man  Republic of Korea
# 19968                                 416  30-34  Man        South Korea
# 19990                                 455  25-29  Man  Republic of Korea
#
#                                                       Q4  \
# 39                                       Master’s degree
# 234                                  Professional degree
# 286                                    Bachelor’s degree
# 366                                      Master’s degree
# 371                                      Master’s degree
# ...                                                  ...
# 19763  Some college/university study without earning ...
# 19845                                    Master’s degree
# 19867                                    Doctoral degree
# 19968                                  Bachelor’s degree
# 19990                                    Doctoral degree
#
#                               Q5          Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# 39        Currently not employed  5-10 years    Python         R       NaN
# 234                 Data Analyst  5-10 years    Python         R       SQL
# 286       Currently not employed   1-2 years    Python       NaN       NaN
# 366                      Student   3-5 years    Python       NaN       NaN
# 371      Product/Project Manager   < 1 years    Python       NaN       NaN
# ...                          ...         ...       ...       ...       ...
# 19763                    Student   < 1 years    Python       NaN       NaN
# 19845                    Student   1-2 years    Python       NaN       SQL
# 19867             Data Scientist   3-5 years    Python       NaN       NaN
# 19968               Data Analyst   1-2 years    Python       NaN       SQL
# 19990  Machine Learning Engineer  5-10 years    Python       NaN       NaN
#
#        ... Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4   Q35_B_Part_5 Q35_B_Part_6  \
# 39     ...          NaN          NaN          NaN   TensorBoard           NaN
# 234    ...          NaN          NaN          NaN            NaN          NaN
# 286    ...          NaN          NaN          NaN            NaN          NaN
# 366    ...          NaN          NaN          NaN            NaN          NaN
# 371    ...          NaN          NaN          NaN            NaN          NaN
# ...    ...          ...          ...          ...            ...          ...
# 19763  ...          NaN          NaN          NaN            NaN          NaN
# 19845  ...          NaN          NaN          NaN            NaN          NaN
# 19867  ...          NaN          NaN          NaN            NaN          NaN
# 19968  ...          NaN          NaN          NaN            NaN          NaN
# 19990  ...          NaN          NaN          NaN            NaN          NaN
#
#       Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9 Q35_B_Part_10 Q35_B_OTHER
# 39             NaN          NaN          NaN           NaN         NaN
# 234            NaN          NaN          NaN          None         NaN
# 286            NaN          NaN          NaN           NaN         NaN
# 366            NaN          NaN          NaN           NaN         NaN
# 371            NaN          NaN          NaN          None         NaN
# ...            ...          ...          ...           ...         ...
# 19763          NaN          NaN          NaN          None         NaN
# 19845          NaN          NaN          NaN           NaN         NaN
# 19867          NaN          NaN          NaN           NaN         NaN
# 19968          NaN          NaN          NaN           NaN         NaN
# 19990          NaN          NaN          NaN           NaN         NaN
#
# [266 rows x 355 columns]

# %%
kQ4 = korea['Q4']
kQ4.value_counts()
# Out:
# Master’s degree                                                      82
# Bachelor’s degree                                                    68
# Doctoral degree                                                      40
# Some college/university study without earning a bachelor’s degree    34
# Professional degree                                                  10
# No formal education past high school                                  8
# I prefer not to answer                                                5
# Name: Q4, dtype: int64

# %%
plt.figure(figsize=(12,12))
sns.countplot(y="Q4", data = korea[1:])
plt.show()

# %%
plt.figure(figsize=(12, 12))
plt.pie(kQ4.value_counts(),
       labels =  kQ4.value_counts().index,
        autopct='%.2f%%',
        colors=sns.color_palette('hls',len(Q22.value_counts().index)),
       textprops={'fontsize':24})
plt.axis('equal')
plt.title("Pie chart for Q22 column", fontsize=48, pad=50)
plt.show()
